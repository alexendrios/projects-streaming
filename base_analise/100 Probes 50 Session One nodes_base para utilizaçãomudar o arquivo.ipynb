# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sad-stone.csv')

# %%
df.shape
# Out:
# (100, 55)

# %%
df.columns
# Out:
# Index(['Probe Number', 'Probe Name', 'OS', 'Media', 'Test start time',
#        'Test duration', 'Connection start time', 'Connection duration',
#        'callSetupTime', 'score', 'sessionNumber', 'inSessionIdx', 'networking',
#        'firewall', 'browser', 'location', 'status', 'URL', 'reason',
#        'audioBitrate_In', 'audioBitrate_Out', 'audioBitrate_In_Max',
#        'audioBitrate_In_Min', 'audioBitrate_Out_Max', 'audioBitrate_Out_Min',
#        'audioPackets_In', 'audioPacketsLoss_In', 'audioPacketsLossPercent_In',
#        'audioPackets_Out', 'audioPacketsLoss_Out',
#        'audioPacketsLossPercent_Out', 'audioJitter_In', 'audioJitter_In_Max',
#        'audioJitter_Out', 'audioJitter_Out_Max', 'audioRoundtrip',
#        'audioRoundtrip_Max', 'videoBitrate_In', 'videoBitrate_Out',
#        'videoBitrate_In_Max', 'videoBitrate_In_Min', 'videoBitrate_Out_Max',
#        'videoBitrate_Out_Min', 'videoPackets_In', 'videoPacketsLoss_In',
#        'videoPacketsLossPercent_In', 'videoPackets_Out',
#        'videoPacketsLoss_Out', 'videoPacketsLossPercent_Out', 'videoJitter_In',
#        'videoJitter_In_Max', 'videoJitter_Out', 'videoJitter_Out_Max',
#        'videoRoundtrip', 'videoRoundtrip_Max'],
#       dtype='object')

# %%
df1 = df.query('score > 0')
df1
# Out:
#     Probe Number     Probe Name     OS                Media  \
# 0              1  sad-stone-001  Linux  VOA-VGA04 (480x640)
# 1              2  sad-stone-002  Linux    VOA-VGA (480x640)
# 2              3  sad-stone-003  Linux  VOA-VGA04 (480x640)
# 3              4  sad-stone-004  Linux    VOA-VGA (480x640)
# 4              5  sad-stone-005  Linux  VOA-VGA04 (480x640)
# ..           ...            ...    ...                  ...
# 95            96  sad-stone-096  Linux    VOA-VGA (480x640)
# 96            97  sad-stone-097  Linux  VOA-VGA04 (480x640)
# 97            98  sad-stone-098  Linux    VOA-VGA (480x640)
# 98            99  sad-stone-099  Linux  VOA-VGA04 (480x640)
# 99           100  sad-stone-100  Linux    VOA-VGA (480x640)
#
#              Test start time  Test duration     Connection start time  \
# 0   2021-03-23T20:09:10.546Z        843.620  2021-03-23T20:11:45.496Z
# 1   2021-03-23T20:09:10.548Z        388.634  2021-03-23T20:12:56.012Z
# 2   2021-03-23T20:09:10.549Z        397.922  2021-03-23T20:11:10.001Z
# 3   2021-03-23T20:09:10.549Z        394.051  2021-03-23T20:12:56.137Z
# 4   2021-03-23T20:09:10.550Z        371.762  2021-03-23T20:11:55.606Z
# ..                       ...            ...                       ...
# 95  2021-03-23T20:09:10.661Z        377.625  2021-03-23T20:12:43.346Z
# 96  2021-03-23T20:09:10.662Z        397.172  2021-03-23T20:12:55.291Z
# 97  2021-03-23T20:09:10.665Z        393.658  2021-03-23T20:13:04.945Z
# 98  2021-03-23T20:09:10.666Z        393.325  2021-03-23T20:12:06.083Z
# 99  2021-03-23T20:09:10.667Z        379.637  2021-03-23T20:12:45.326Z
#
#     Connection duration  callSetupTime  score  ...  \
# 0               681.177          73.49    5.8  ...
# 1               108.246           3.28    5.6  ...
# 2               217.982         113.99    5.9  ...
# 3               112.006           4.04    5.7  ...
# 4               140.347          39.67    5.2  ...
# ..                  ...            ...    ...  ...
# 95              152.900           4.04    5.4  ...
# 96              124.740          27.79    5.7  ...
# 97              114.998          11.00    6.0  ...
# 98              153.119          42.63    5.6  ...
# 99              113.997           3.00    5.7  ...
#
#     videoPacketsLossPercent_In  videoPackets_Out videoPacketsLoss_Out  \
# 0                          0 %             17351                  0.0
# 1                          0 %              9905                  8.0
# 2                          0 %             22263                  1.0
# 3                          0 %             11030                  0.0
# 4                          0 %             11482                 43.0
# ..                         ...               ...                  ...
# 95                         0 %             15011                 41.0
# 96                         0 %             10127                  0.0
# 97                         0 %             10020                 11.0
# 98                         0 %             13786                  0.0
# 99                         0 %             10757                231.0
#
#    videoPacketsLossPercent_Out videoJitter_In videoJitter_In_Max  \
# 0                          0 %          77.01             100.10
# 1                       0.08 %         678.61            1542.00
# 2                       0.00 %         360.45             754.00
# 3                          0 %         854.59            2342.53
# 4                       0.37 %         216.72           15601.33
# ..                         ...            ...                ...
# 95                      0.27 %         603.97            1675.00
# 96                         0 %          58.50              76.39
# 97                      0.11 %         196.25             590.88
# 98                         0 %         391.98            1726.24
# 99                      2.15 %         516.89            1370.09
#
#    videoJitter_Out videoJitter_Out_Max videoRoundtrip  videoRoundtrip_Max
# 0             7.59               72.91          27.68                 306
# 1             9.13              105.29          32.25                 292
# 2             6.44               17.94          22.28                 130
# 3             8.31               79.71          25.36                 194
# 4             9.52               46.98          27.44                 415
# ..             ...                 ...            ...                 ...
# 95            6.73               60.73          42.17                1086
# 96            7.74               51.37          40.66                 826
# 97            6.86               55.47          29.78                 199
# 98            7.50               23.28          26.42                 232
# 99            8.90              152.79          33.07                1018
#
# [84 rows x 55 columns]

# %%
erro = df['reason']
info = []
for i in erro:
    info.append(i)

# %%
info
# Out:
# ['Error while running .elementSubmit) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/marca-szd.png - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'https:/www.staging.liviasaude.com.br/assetslv2/js/owl.carousel.min.js - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Test timeout after 1020s',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500414ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500362ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/logo-livia-azul.svg - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/seta-next.svg - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/img-consultas-mobile.jpg - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500219ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'Test timeout after 1020s',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500035ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'Test timeout after 1020s',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500166ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .setElementValue) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/img-consultas-mobile.jpg - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .clickElement) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .elementSubmit) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500155ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'https:/www.staging.liviasaude.com.br/assetslv2/js/scripts.min.js - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .elementSubmit) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .elementSubmit) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  "https:/www.staging.liviasaude.com.br/vendors~main-bdd68c069090be26c58d.js 1:938443 Uncaught TypeError: Cannot read property 'addEventListener' of null",
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Test timeout after 1020s',
#  ' Timed out while waiting for element <#header > div.header-container > div.header-topo > a> to be present for 500000 milliseconds. - expected "visible" but got: "not found" (500170ms), waitForElementVisible (\'#header > div.header-container > div.header-topo > a\', 500000) (Line:196)',
#  'https:/www.staging.liviasaude.com.br/assetslv2/img/marca-delboni.svg - Failed to load resource: the server responded with a status of 502 (Bad Gateway)',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.',
#  'Error while running .clickElement) protocol action: stale element reference: element is not attached to the page document',
#  'Error while running .navigateTo) protocol action: An unknown error has occurred.']

# %%
len(info)
# Out:
# 100

# %%
#contando a quantidade de valores distintos em cada uma das colunas
for colunas in list(df.columns):
  print( "{0:25} {1}".format(colunas, df[colunas].nunique()) )
# Out:
# Probe Number              100
# Probe Name                100
# OS                        1
# Media                     2
# Test start time           65
# Test duration             97
# Connection start time     85
# Connection duration       84
# callSetupTime             76
# score                     17
# sessionNumber             50
# inSessionIdx              2
# networking                1
# firewall                  1
# browser                   1
# location                  1
# status                    3
# URL                       100
# reason                    20
# audioBitrate_In           84
# audioBitrate_Out          69
# audioBitrate_In_Max       85
# audioBitrate_In_Min       23
# audioBitrate_Out_Max      73
# audioBitrate_Out_Min      73
# audioPackets_In           85
# audioPacketsLoss_In       26
# audioPacketsLossPercent_In 15
# audioPackets_Out          75
# audioPacketsLoss_Out      48
# audioPacketsLossPercent_Out 51
# audioJitter_In            83
# audioJitter_In_Max        55
# audioJitter_Out           72
# audioJitter_Out_Max       74
# audioRoundtrip            74
# audioRoundtrip_Max        65
# videoBitrate_In           85
# videoBitrate_Out          75
# videoBitrate_In_Max       85
# videoBitrate_In_Min       65
# videoBitrate_Out_Max      75
# videoBitrate_Out_Min      75
# videoPackets_In           85
# videoPacketsLoss_In       1
# videoPacketsLossPercent_In 1
# videoPackets_Out          74
# videoPacketsLoss_Out      31
# videoPacketsLossPercent_Out 26
# videoJitter_In            85
# videoJitter_In_Max        85
# videoJitter_Out           71
# videoJitter_Out_Max       75
# videoRoundtrip            75
# videoRoundtrip_Max        70

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, minimal=True)
profile.to_file("Analise_dados_01_node_100_50.html")
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=63.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
